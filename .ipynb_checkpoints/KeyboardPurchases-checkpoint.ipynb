# %%
import pandas as pd
from matplotlib import pyplot as plt
# %matplotlib inline
import seaborn as sns

# https://stackoverflow.com/a/17303428 - original answer for color coordination in print statements
class color:
   PURPLE = '\033[95m'
   CYAN = '\033[96m'
   DARKCYAN = '\033[36m'
   BLUE = '\033[94m'
   GREEN = '\033[92m'
   YELLOW = '\033[93m'
   RED = '\033[91m'
   BOLD = '\033[1m'
   UNDERLINE = '\033[4m'
   END = '\033[0m'
    

# purchases = "https://raw.githubusercontent.com/iitsalex/Keyboard-Data-Testing/master/purchases-sheet.csv"
# google docs file must be edited at the end to include /export?gid-...- in order to import correctly
# https://stackoverflow.com/a/35246041 - original answer
purchases = "https://docs.google.com/spreadsheets/d/1dxvffAQC1SNPVGqKWQyUGLGGduABcw-r-JswAWowZso/export?gid=0&format=csv"
data = pd.read_csv(purchases)
# data = pd.read_csv(purchased, index_col=0) # to remove the ID/Index field on the left
data
# Out:
#                         Item   Paid  Value   Status            Type  \
# 0       Rotary Encoders (5x)   9.62   9.62  Present  Part/Accessory
# 1              Diodes (100x)   4.29   4.29  Present  Part/Accessory
# 2             Pro Micro (3x)  16.00  16.00  Present  Part/Accessory
# 3                Planck Case  10.81   8.00  Present  Part/Accessory
# 4         Let's Split Screws   3.45   3.45  Present  Part/Accessory
# ..                       ...    ...    ...      ...             ...
# 101                 Spudgers   2.40   2.40  Present  Part/Accessory
# 102    Cringe Booty Spacebar   4.98   4.98  Present         Keycaps
# 103               KAT Blanks  55.00  55.00       GB         Keycaps
# 104     Kanye Keycap (extra)  77.00  77.00     Sold         Keycaps
# 105  Kanye Keycap (original)   0.00  77.00  Present         Keycaps
#
#     Purchased From Date Purchased Notes
# 0           Amazon         8/2020   NaN
# 1           Amazon         8/2020   NaN
# 2           Amazon         8/2020   NaN
# 3           Amazon         6/2020   NaN
# 4           Amazon         6/2020   NaN
# ..             ...            ...   ...
# 101     Aliexpress         3/2020   NaN
# 102     Aliexpress         1/2020   NaN
# 103  ApexKeyboards         6/2020   NaN
# 104     Mechmarket         9/2020   NaN
# 105     Mechmarket         6/2020   NaN
#
# [106 rows x 8 columns]

# %%
total_paid = data.Paid.sum()
print(f'Total Paid: {total_paid}')

net_value_raw = data.Value.sum()
print(f'Net Value (Raw/Unadjusted): {net_value_raw}')
# Out:
# Total Paid: 7060.18
# Net Value (Raw/Unadjusted): 9465.17

# %%
types = data.Type.unique()
current_cash_invested = 0

print(color.BOLD + "Type Totals" + color.END)
for t in types:
    new_df = data[data["Type"] == t]
    net_cost_df = new_df[new_df["Status"] == "Sold"]
    
    total = len(new_df.index)
    paid_total = round(new_df.Paid.sum(), 2)
    value_total = round(new_df.Value.sum(), 2)
    net_damage = round(paid_total - round(net_cost_df.Value.sum(), 2), 2)
    
    current_cash_invested += net_damage
    
    print(f'{color.BLUE}{t}: {total} items{color.END}')
    print(f'Paid: ${paid_total}')
    print(f'Value: ${value_total}')
    print(f'Net Damage: ${net_damage}')
    
print(f'\nCurrent Cash Invested: ${current_cash_invested}')
# Out:
# Type Totals
# Part/Accessory: 34 items
# Paid: $653.4
# Value: $700.1
# Net Damage: $544.9
# Switches: 22 items
# Paid: $899.57
# Value: $1226.63
# Net Damage: $485.14
# Lube: 8 items
# Paid: $95.28
# Value: $95.28
# Net Damage: $95.28
# Keyboard: 10 items
# Paid: $2277.25
# Value: $2870.0
# Net Damage: $2027.25
# Keycaps: 22 items
# Paid: $2810.68
# Value: $4109.16
# Net Damage: $2138.5
# Deskpad: 10 items
# Paid: $324.0
# Value: $464.0
# Net Damage: $160.0
#
# Current Cash Invested: $5451.07

# %%
types = data.Status.unique()
current_cash_invested = 0

print(color.BOLD + "Status Totals" + color.END)
for t in types:
    new_df = data[data["Status"] == t]
    
    total = len(new_df.index)
    paid_total = round(new_df.Paid.sum(), 2)
    value_total = round(new_df.Value.sum(), 2)
    
    print(f'{color.BLUE}{t}: {total} items{color.END}')
    print(f'Paid: ${paid_total}')
    print(f'Value: ${value_total}')
# Out:
# Status Totals
# Present: 60 items
# Paid: $2520.81
# Value: $3386.06
# Sold: 26 items
# Paid: $1463.76
# Value: $1609.11
# GB: 20 items
# Paid: $3075.61
# Value: $4470.0

# %%
data[data["Type"] == "Keycaps"]
# Out:
#                                  Item    Paid   Value   Status     Type  \
# 18         GMK Bushido (Base + Nomad)  195.02  330.00       GB  Keycaps
# 22    KAT Milkshake Ortho + Katakanas  105.18  105.18     Sold  Keycaps
# 23                GMK Camping R2 Base  185.00  260.00  Present  Keycaps
# 25           GMK Camping R2 Novelties   60.00   80.00  Present  Keycaps
# 29                GMK Olivia Base Kit  195.02  300.00  Present  Keycaps
# 30   GMK Olivia Extension + Spacebars   90.48  130.00  Present  Keycaps
# 33                           DSA Caps   16.00   16.00     Sold  Keycaps
# 37                         GMK Fro.yo  220.00  270.00  Present  Keycaps
# 43                       KAT Mizu set  162.00  250.00       GB  Keycaps
# 44              KAT Mizu set (Harold)  144.00  144.00     Sold  Keycaps
# 54                GMK First Love Base  186.00  250.00     Sold  Keycaps
# 57                  Keyforge Artisans  150.00  200.00       GB  Keycaps
# 63     KAT Milkshake Kata+Mods+Fruits  147.00  350.00  Present  Keycaps
# 67                      GMK Nord base  125.00  250.00       GB  Keycaps
# 72          Infinikey Islander Bundle  160.00  280.00       GB  Keycaps
# 78                       GMK Oblivion  280.00  300.00  Present  Keycaps
# 80                      Gengar Keycap   35.00   80.00     Sold  Keycaps
# 85                       GMK Laser R2  218.00  300.00       GB  Keycaps
# 102             Cringe Booty Spacebar    4.98    4.98  Present  Keycaps
# 103                        KAT Blanks   55.00   55.00       GB  Keycaps
# 104              Kanye Keycap (extra)   77.00   77.00     Sold  Keycaps
# 105           Kanye Keycap (original)    0.00   77.00  Present  Keycaps
#
#     Purchased From Date Purchased                    Notes
# 18       NovelKeys         4/2020                      NaN
# 22       NovelKeys         6/2020                      NaN
# 23       NovelKeys         8/2020                      NaN
# 25       NovelKeys         8/2020                      NaN
# 29       NovelKeys         9/2020  Yeehaw extras go brrrrr
# 30       NovelKeys         9/2020                      NaN
# 33      Flashquark         5/2020                      NaN
# 37       ZFrontier         9/2020                      NaN
# 43      Cannonkeys         9/2020                      NaN
# 44      Cannonkeys         9/2020                      NaN
# 54      Cannonkeys         8/2020                      NaN
# 57        Keyforge         7/2020                      NaN
# 63       ZFrontier         7/2020                      NaN
# 67         MKUltra         7/2020                      NaN
# 72   TheKeyCompany         5/2020                      NaN
# 78      Mechmarket         8/2020                      NaN
# 80      Mechmarket         5/2020                      NaN
# 85            Drop         7/2020                      NaN
# 102     Aliexpress         1/2020                      NaN
# 103  ApexKeyboards         6/2020                      NaN
# 104     Mechmarket         9/2020                      NaN
# 105     Mechmarket         6/2020                      NaN

# %%
data[data["Status"] == "GB"].sort_values(by=['Date Purchased'])
# Out:
#                                                   Item     Paid   Value  \
# 18                          GMK Bushido (Base + Nomad)   195.02   330.0
# 73                         Infinikey Islander Deskpad     20.00    50.0
# 72                           Infinikey Islander Bundle   160.00   280.0
# 79          Ikki68 Keyboard (White/Gold) + Brass Plate   322.89   450.0
# 103                                         KAT Blanks    55.00    55.0
# 85                                        GMK Laser R2   218.00   300.0
# 57                                   Keyforge Artisans   150.00   200.0
# 58                                UHMWPE Linear Stems     19.49    40.0
# 66                                    Dogikon Switches    42.96    70.0
# 67                                       GMK Nord base   125.00   250.0
# 68                                    GMK Nord deskmat    30.00    30.0
# 36                                   Think6.5V2 Bundle  1145.80  1600.0
# 47   Ikki68 Extras (PCB, POM plate, 3x badges + 1x ...   160.00   180.0
# 48                                         Uwu deskmat    30.00    50.0
# 50                                  Moody moon deskmat    30.00    50.0
# 41                                           8008 Inks    72.00   100.0
# 43                                        KAT Mizu set   162.00   250.0
# 39                                         OA Switches    50.00    70.0
# 38                                        JTK Max Tray    35.00    35.0
# 40                                        YOK Panda V2    52.45    80.0
#
#     Status            Type Purchased From Date Purchased Notes
# 18      GB         Keycaps      NovelKeys         4/2020   NaN
# 73      GB         Deskpad  TheKeyCompany         5/2020   NaN
# 72      GB         Keycaps  TheKeyCompany         5/2020   NaN
# 79      GB        Keyboard    WuqueStudio         6/2020   NaN
# 103     GB         Keycaps  ApexKeyboards         6/2020   NaN
# 85      GB         Keycaps           Drop         7/2020   NaN
# 57      GB         Keycaps       Keyforge         7/2020   NaN
# 58      GB  Part/Accessory           Drop         7/2020   NaN
# 66      GB        Switches    InfinityKey         7/2020   NaN
# 67      GB         Keycaps        MKUltra         7/2020   NaN
# 68      GB         Deskpad        MKUltra         7/2020   NaN
# 36      GB        Keyboard     GrayStudio         7/2020   NaN
# 47      GB  Part/Accessory    WuqueStudio         8/2020   NaN
# 48      GB         Deskpad   MalvixStudio         8/2020   NaN
# 50      GB         Deskpad  TheKeyCompany         8/2020   NaN
# 41      GB        Switches      Dixiemech         9/2020   NaN
# 43      GB         Keycaps     Cannonkeys         9/2020   NaN
# 39      GB        Switches      Mech.Land         9/2020   NaN
# 38      GB  Part/Accessory      ThoccLabs         9/2020   NaN
# 40      GB        Switches    InfinityKey         9/2020   NaN

# %%
sns.catplot(
    data=data, 
    x="Paid",
    y="Type",
    aspect=1, # aspect change the aspect ratio
    kind="box",
    height=10,
    palette="Paired"
    ) 
plt.title("Prices paid based on type of item");

# %%
g=sns.catplot(
    data=data,
    x="Paid",
    y="Purchased From",
    kind="box",
    hue="Date Purchased",
)
g.fig.suptitle("Test", y=1.05);

# %%
g=sns.catplot(
    data=data,
    x="Type",
    y="Paid",
    kind="violin",
    cut=0,
    bw=0.2,
    scale="count",
    )

g.fig.suptitle("Price Paid for different types of keyboard purchases", y=1.05);

# %%
g=sns.catplot(
    data=data,
    x="Type",
    y="Value",
    kind="violin",
    cut=0,
    bw=0.2,
    scale="count",
    )

g.fig.suptitle("Value for different types of keyboard purchases", y=1.05);

# %%
expensive_df = data[data["Value"] > 200]

sns.catplot(
    data=expensive_df, 
    x="Type",
    y="Paid",
    aspect=1, # aspect change the aspect ratio
    kind="swarm",
    height=5,
    palette="gist_heat"
    ) 
plt.title("Temp");

# %%
sns.catplot(
    data=data, 
    x="Paid",
    y="Type",
    aspect=1, # aspect change the aspect ratio
    kind="swarm",
    height=10,
    palette="gist_heat"
    ) 
plt.title("Temp");
